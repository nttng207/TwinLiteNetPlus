# %%
# !git clone https://github.com/nttng207/TwinLiteNetPlus.git --branch develop/thongnguyen
# Out:
# Cloning into 'TwinLiteNetPlus'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 147 (delta 46), reused 35 (delta 35), pack-reused 93 (from 1)
# Receiving objects: 100% (147/147), 11.70 MiB | 36.32 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# %%bash
# sed -i \
#   -e "s|self.root='../bdd100k/images/val'|self.root='/kaggle/input/bdd100k/bdd100k/images/val'|" \
#   -e "s|self.root='../bdd100k/images/train'|self.root='/kaggle/input/bdd100k/bdd100k/images/train'|" \
#   /kaggle/working/TwinLiteNetPlus/BDD100K.py

# %%
# !pip install -q gdown
# !mkdir -p /kaggle/working/TwinLiteNetPlus/pretrained

# %%
# !gdown --folder "https://drive.google.com/drive/folders/1EqBzUw0b17aEumZmWYrGZmbx_XJqU-vz" \
  -O /kaggle/working/TwinLiteNetPlus/pretrained
# Out:
# Retrieving folder contents
# Processing file 1H8P-GrOUBOaVs5LEqXBfz0dC9gguUUio large.pth
# Processing file 121z9XUh7_lgze8i6nS6Ne2HQ7ZG5_uG9 medium.pth
# Processing file 1SvD03WZOq8eN4X0bMFNZyzj4upZM1QVl nano.pth
# Processing file 1N7jNsa8P1dM-UevqPRsx6heUpN4L00FJ small.pth
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1H8P-GrOUBOaVs5LEqXBfz0dC9gguUUio
# To: /kaggle/working/TwinLiteNetPlus/pretrained/large.pth
# 100%|██████████████████████████████████████| 7.96M/7.96M [00:00<00:00, 29.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=121z9XUh7_lgze8i6nS6Ne2HQ7ZG5_uG9
# To: /kaggle/working/TwinLiteNetPlus/pretrained/medium.pth
# 100%|███████████████████████████████████████| 2.05M/2.05M [00:00<00:00, 190MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SvD03WZOq8eN4X0bMFNZyzj4upZM1QVl
# ...

# %%
# %cd /kaggle/working/TwinLiteNetPlus
# !python val.py --config 'nano' --weight 'pretrained/nano.pth' --num_workers 8 --batch_size 16
# Out:
# /kaggle/working/TwinLiteNetPlus
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Total network parameters: 33379
# Driving Area Segment: mIOU(0.874)
# Lane Line Segment: Acc(0.702) IOU(0.234)

# %%
# %cd /kaggle/working/TwinLiteNetPlus
# !python val.py --config 'small' --weight 'pretrained/small.pth' --num_workers 8 --batch_size 16
# Out:
# /kaggle/working/TwinLiteNetPlus
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Total network parameters: 121552
# Driving Area Segment: mIOU(0.906)
# Lane Line Segment: Acc(0.758) IOU(0.293)

# %%
# %cd /kaggle/working/TwinLiteNetPlus
# !python val.py --config 'medium' --weight 'pretrained/medium.pth' --num_workers 8 --batch_size 16
# Out:
# /kaggle/working/TwinLiteNetPlus
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Total network parameters: 478876
# Driving Area Segment: mIOU(0.920)
# Lane Line Segment: Acc(0.791) IOU(0.324)

# %%
# %cd /kaggle/working/TwinLiteNetPlus
# !python val.py --config 'large' --weight 'pretrained/large.pth' --num_workers 8 --batch_size 16
# Out:
# /kaggle/working/TwinLiteNetPlus
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Total network parameters: 1943911
# Driving Area Segment: mIOU(0.929)
# Lane Line Segment: Acc(0.819) IOU(0.342)
